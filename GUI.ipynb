# %%
from tkinter import *
from tkinter.ttk import Combobox
from tkinter import scrolledtext
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
import Back

# %%
window = Tk()
window.title("PVT Calculator ")
window.geometry('1000x1000')
window.resizable(width=0, height=0)

def calculate():
    p = float(e0.get())
    pb = float(e1.get())
    t = float(e2.get())
    so = float(e3.get())
    sg = float(e4.get())
    nacl = float(e5.get())
    method1=e7.get()
    method2=e8.get()
    method3=e9.get()
    method4=e10.get()
    method5=e11.get()
    method6=e12.get()
    method7=e13.get()
    
    rho=Back.rho_Std(p,pb,t,sg,so)
    Bo=Back.BO(p,pb,t,so,sg,method1)
    gor=Back.GOR(p,pb,t,so,sg,method2)
    miuo=Back.MIUO(p,pb,t,so,sg,method3)
    co=Back.co_Vzq(p,pb,t,sg,so)
    z=Back.ZF(p,t,sg,method4)
    rhg=Back.rho_g(p,t,sg)
    bg=Back.Bg(p,t,sg)
    miug=Back.miug_lee(p,t,sg)
    cg=Back.CG(p,t,sg,method5)
    bw=Back.BW(p,pb,t,nacl,method6)
    rhw=Back.rhow_mcn(p,pb,t,nacl)
    miuw=Back.MIUW(p,t,nacl,method7)
    
    E0.delete(0, END)
    E0.insert(END, "{:.4f}" .format(rho))
    E1.delete(0, END)
    E1.insert(END, "{:.4f}" .format(Bo))
    E2.delete(0, END)
    E2.insert(END, "{:.4f}" .format(gor))
    E3.delete(0, END)
    E3.insert(END, "{:.4f}" .format(miuo))
    E4.delete(0, END)
    E4.insert(END, "{:.7f}" .format(co))
    E5.delete(0, END)
    E5.insert(END, "{:.4f}" .format(z))
    E6.delete(0, END)
    E6.insert(END, "{:.4f}" .format(rhg))
    E7.delete(0, END)
    E7.insert(END, "{:.4f}" .format(bg))
    E8.delete(0, END)
    E8.insert(END, "{:.4f}" .format(miug))
    E9.delete(0, END)
    E9.insert(END, "{:.4f}" .format(cg))
    E10.delete(0, END)
    E10.insert(END, "{:.4f}" .format(bw))
    E11.delete(0, END)
    E11.insert(END, "{:.4f}" .format(rhw))
    E12.delete(0, END)
    E12.insert(END, "{:.4f}" .format(miuw))

def clear():
    E0.delete(0, END)
    E1.delete(0, END)
    E2.delete(0, END)
    E3.delete(0, END)
    E4.delete(0, END)
    E5.delete(0, END)
    E6.delete(0, END)
    E7.delete(0, END)
    E8.delete(0, END)
    E9.delete(0, END)
    E10.delete(0, END)
    E11.delete(0, END)
    E12.delete(0, END)

def Run():
    table1.delete(1.0, END)
    for p in range(int(e0.get()),100,-100):
        pb = float(e1.get())
        t = float(e2.get())
        so = float(e3.get())
        sg = float(e4.get())
        nacl = float(e5.get())
        method1=e7.get()
        method2=e8.get()
        method3=e9.get()
        method4=e10.get()
        method5=e11.get()
        method6=e12.get()
        method7=e13.get()
    
        rho=Back.rho_Std(p,pb,t,sg,so)
        Bo=Back.BO(p,pb,t,so,sg,method1)
        gor=Back.GOR(p,pb,t,so,sg,method2)
        miuo=Back.MIUO(p,pb,t,so,sg,method3)
        co=Back.co_Vzq(p,pb,t,sg,so)
        z=Back.ZF(p,t,sg,method4)
        rhg=Back.rho_g(p,t,sg)
        bg=Back.Bg(p,t,sg)
        miug=Back.miug_lee(p,t,sg)
        cg=Back.CG(p,t,sg,method5)
        bw=Back.BW(p,pb,t,nacl,method6)
        rhw=Back.rhow_mcn(p,pb,t,nacl)
        miuw=Back.MIUW(p,t,nacl,method7)
    
        table1.insert(END," {:3d}\t {:4.3f}\t  {:4.3f}\t   {:4.3f}\t   {:4.3f}\t  {:4.3f}\t  {:4.3f}\t  {:4.3f}\t   {:4.3f}\t   {:4.3f}\t   {:4.3f}\t   {:4.3f}\t   {:4.3f}\t {:4.3f}\n".format(p,rho,Bo,gor,miuo,co,z,rhg,bg,miug,cg,bw,rhw,miuw)) 

def GORPlot():
    plotwindow=Toplevel(window)
    p = float(e0.get())
    pb = float(e1.get())
    t = float(e2.get())
    so = float(e3.get())
    sg = float(e4.get())
    nacl = float(e5.get())
    method1=e7.get()
    method2=e8.get()
    method3=e9.get()
    method4=e10.get()
    method5=e11.get()
    method6=e12.get()
    method7=e13.get()
    
    rho=Back.rho_Std(p,pb,t,sg,so)
    Bo=Back.BO(p,pb,t,so,sg,method1)
    gor=Back.GOR(p,pb,t,so,sg,method2)
    miuo=Back.MIUO(p,pb,t,so,sg,method3)
    co=Back.co_Vzq(p,pb,t,sg,so)
    z=Back.ZF(p,t,sg,method4)
    rhg=Back.rho_g(p,t,sg)
    bg=Back.Bg(p,t,sg)
    miug=Back.miug_lee(p,t,sg)
    cg=Back.CG(p,t,sg,method5)
    bw=Back.BW(p,pb,t,nacl,method6)
    rhw=Back.rhow_mcn(p,pb,t,nacl)
    miuw=Back.MIUW(p,t,nacl,method7)

    x=range(int(e0.get()),100,-100)
    y=[Back.GOR(p,pb,t,so,sg,method2) for p in x]
    fig=plt.Figure(figsize=(10,10))
    a=fig.add_subplot(111)
    a.plot(x,y)
    a.set_title('GOR vs Pressure')
    a.set_xlabel('Pressure(Psia)')
    a.set_ylabel('GOR (scf/stb)')
    chart1=FigureCanvasTkAgg(fig,plotwindow)
    chart1.get_tk_widget().pack()

def RHOOPlot():
    plotwindow=Toplevel(window)
    p = float(e0.get())
    pb = float(e1.get())
    t = float(e2.get())
    so = float(e3.get())
    sg = float(e4.get())
    nacl = float(e5.get())
    method1=e7.get()
    method2=e8.get()
    method3=e9.get()
    method4=e10.get()
    method5=e11.get()
    method6=e12.get()
    method7=e13.get()
    
    rho=Back.rho_Std(p,pb,t,sg,so)
    Bo=Back.BO(p,pb,t,so,sg,method1)
    gor=Back.GOR(p,pb,t,so,sg,method2)
    miuo=Back.MIUO(p,pb,t,so,sg,method3)
    co=Back.co_Vzq(p,pb,t,sg,so)
    z=Back.ZF(p,t,sg,method4)
    rhg=Back.rho_g(p,t,sg)
    bg=Back.Bg(p,t,sg)
    miug=Back.miug_lee(p,t,sg)
    cg=Back.CG(p,t,sg,method5)
    bw=Back.BW(p,pb,t,nacl,method6)
    rhw=Back.rhow_mcn(p,pb,t,nacl)
    miuw=Back.MIUW(p,t,nacl,method7)

    x=range(int(e0.get()),100,-100)
    y=[Back.MIUO(p,pb,t,so,sg,method3) for p in x]
    fig=plt.Figure(figsize=(10,10))
    a=fig.add_subplot(111)
    a.plot(x,y)
    a.set_title('Oil Density vs Pressure')
    a.set_xlabel('Pressure(Psia)')
    a.set_ylabel('Oil Density (lb/ft3)')
    chart1=FigureCanvasTkAgg(fig,plotwindow)
    chart1.get_tk_widget().pack()

def BOPlot():
    plotwindow=Toplevel(window)
    p = float(e0.get())
    pb = float(e1.get())
    t = float(e2.get())
    so = float(e3.get())
    sg = float(e4.get())
    nacl = float(e5.get())
    method1=e7.get()
    method2=e8.get()
    method3=e9.get()
    method4=e10.get()
    method5=e11.get()
    method6=e12.get()
    method7=e13.get()
    
    rho=Back.rho_Std(p,pb,t,sg,so)
    Bo=Back.BO(p,pb,t,so,sg,method1)
    gor=Back.GOR(p,pb,t,so,sg,method2)
    miuo=Back.MIUO(p,pb,t,so,sg,method3)
    co=Back.co_Vzq(p,pb,t,sg,so)
    z=Back.ZF(p,t,sg,method4)
    rhg=Back.rho_g(p,t,sg)
    bg=Back.Bg(p,t,sg)
    miug=Back.miug_lee(p,t,sg)
    cg=Back.CG(p,t,sg,method5)
    bw=Back.BW(p,pb,t,nacl,method6)
    rhw=Back.rhow_mcn(p,pb,t,nacl)
    miuw=Back.MIUW(p,t,nacl,method7)

    x=range(int(e0.get()),100,-100)
    y=[Back.BO(p,pb,t,so,sg,method1) for p in x]
    fig=plt.Figure(figsize=(10,10))
    a=fig.add_subplot(111)
    a.plot(x,y)
    a.set_title('FVF Oil vs Pressure')
    a.set_xlabel('Pressure(Psia)')
    a.set_ylabel('FVF Oil (rb/stb)')
    chart1=FigureCanvasTkAgg(fig,plotwindow)
    chart1.get_tk_widget().pack()
    
def MIUOPlot():
    plotwindow=Toplevel(window)
    p = float(e0.get())
    pb = float(e1.get())
    t = float(e2.get())
    so = float(e3.get())
    sg = float(e4.get())
    nacl = float(e5.get())
    method1=e7.get()
    method2=e8.get()
    method3=e9.get()
    method4=e10.get()
    method5=e11.get()
    method6=e12.get()
    method7=e13.get()
    
    rho=Back.rho_Std(p,pb,t,sg,so)
    Bo=Back.BO(p,pb,t,so,sg,method1)
    gor=Back.GOR(p,pb,t,so,sg,method2)
    miuo=Back.MIUO(p,pb,t,so,sg,method3)
    co=Back.co_Vzq(p,pb,t,sg,so)
    z=Back.ZF(p,t,sg,method4)
    rhg=Back.rho_g(p,t,sg)
    bg=Back.Bg(p,t,sg)
    miug=Back.miug_lee(p,t,sg)
    cg=Back.CG(p,t,sg,method5)
    bw=Back.BW(p,pb,t,nacl,method6)
    rhw=Back.rhow_mcn(p,pb,t,nacl)
    miuw=Back.MIUW(p,t,nacl,method7)

    x=range(int(e0.get()),100,-100)
    y=[Back.MIUO(p,pb,t,so,sg,method3) for p in x]
    fig=plt.Figure(figsize=(10,10))
    a=fig.add_subplot(111)
    a.plot(x,y)
    a.set_title('Oil Viscosity vs Pressure')
    a.set_xlabel('Pressure(Psia)')
    a.set_ylabel('Oil Viscosity (cP)')
    chart1=FigureCanvasTkAgg(fig,plotwindow)
    chart1.get_tk_widget().pack()
    
def COPlot():
    plotwindow=Toplevel(window)
    p = float(e0.get())
    pb = float(e1.get())
    t = float(e2.get())
    so = float(e3.get())
    sg = float(e4.get())
    nacl = float(e5.get())
    method1=e7.get()
    method2=e8.get()
    method3=e9.get()
    method4=e10.get()
    method5=e11.get()
    method6=e12.get()
    method7=e13.get()
    
    rho=Back.rho_Std(p,pb,t,sg,so)
    Bo=Back.BO(p,pb,t,so,sg,method1)
    gor=Back.GOR(p,pb,t,so,sg,method2)
    miuo=Back.MIUO(p,pb,t,so,sg,method3)
    co=Back.co_Vzq(p,pb,t,sg,so)
    z=Back.ZF(p,t,sg,method4)
    rhg=Back.rho_g(p,t,sg)
    bg=Back.Bg(p,t,sg)
    miug=Back.miug_lee(p,t,sg)
    cg=Back.CG(p,t,sg,method5)
    bw=Back.BW(p,pb,t,nacl,method6)
    rhw=Back.rhow_mcn(p,pb,t,nacl)
    miuw=Back.MIUW(p,t,nacl,method7)

    x=range(int(e0.get()),100,-100)
    y=[Back.co_Vzq(p,pb,t,sg,so) for p in x]
    fig=plt.Figure(figsize=(10,10))
    a=fig.add_subplot(111)
    a.plot(x,y)
    a.set_title('Oil Compressibility vs Pressure')
    a.set_xlabel('Pressure(Psia)')
    a.set_ylabel('Oil Compressibility (1/Psia)')
    chart1=FigureCanvasTkAgg(fig,plotwindow)
    chart1.get_tk_widget().pack()
    
def ZPlot():
    plotwindow=Toplevel(window)
    p = float(e0.get())
    pb = float(e1.get())
    t = float(e2.get())
    so = float(e3.get())
    sg = float(e4.get())
    nacl = float(e5.get())
    method1=e7.get()
    method2=e8.get()
    method3=e9.get()
    method4=e10.get()
    method5=e11.get()
    method6=e12.get()
    method7=e13.get()
    
    rho=Back.rho_Std(p,pb,t,sg,so)
    Bo=Back.BO(p,pb,t,so,sg,method1)
    gor=Back.GOR(p,pb,t,so,sg,method2)
    miuo=Back.MIUO(p,pb,t,so,sg,method3)
    co=Back.co_Vzq(p,pb,t,sg,so)
    z=Back.ZF(p,t,sg,method4)
    rhg=Back.rho_g(p,t,sg)
    bg=Back.Bg(p,t,sg)
    miug=Back.miug_lee(p,t,sg)
    cg=Back.CG(p,t,sg,method5)
    bw=Back.BW(p,pb,t,nacl,method6)
    rhw=Back.rhow_mcn(p,pb,t,nacl)
    miuw=Back.MIUW(p,t,nacl,method7)

    x=range(int(e0.get()),100,-100)
    y=[Back.ZF(p,t,sg,method4) for p in x]
    fig=plt.Figure(figsize=(10,10))
    a=fig.add_subplot(111)
    a.plot(x,y)
    a.set_title('Z Factor vs Pressure')
    a.set_xlabel('Pressure(Psia)')
    a.set_ylabel('Z Factor')
    chart1=FigureCanvasTkAgg(fig,plotwindow)
    chart1.get_tk_widget().pack()
    
def RHOGPlot():
    plotwindow=Toplevel(window)
    p = float(e0.get())
    pb = float(e1.get())
    t = float(e2.get())
    so = float(e3.get())
    sg = float(e4.get())
    nacl = float(e5.get())
    method1=e7.get()
    method2=e8.get()
    method3=e9.get()
    method4=e10.get()
    method5=e11.get()
    method6=e12.get()
    method7=e13.get()
    
    rho=Back.rho_Std(p,pb,t,sg,so)
    Bo=Back.BO(p,pb,t,so,sg,method1)
    gor=Back.GOR(p,pb,t,so,sg,method2)
    miuo=Back.MIUO(p,pb,t,so,sg,method3)
    co=Back.co_Vzq(p,pb,t,sg,so)
    z=Back.ZF(p,t,sg,method4)
    rhg=Back.rho_g(p,t,sg)
    bg=Back.Bg(p,t,sg)
    miug=Back.miug_lee(p,t,sg)
    cg=Back.CG(p,t,sg,method5)
    bw=Back.BW(p,pb,t,nacl,method6)
    rhw=Back.rhow_mcn(p,pb,t,nacl)
    miuw=Back.MIUW(p,t,nacl,method7)

    x=range(int(e0.get()),100,-100)
    y=[Back.rho_g(p,t,sg) for p in x]
    fig=plt.Figure(figsize=(10,10))
    a=fig.add_subplot(111)
    a.plot(x,y)
    a.set_title('Gas Density vs Pressure')
    a.set_xlabel('Pressure(Psia)')
    a.set_ylabel('Gas Density (lb/ft3)')
    chart1=FigureCanvasTkAgg(fig,plotwindow)
    chart1.get_tk_widget().pack()
    
def BGPlot():
    plotwindow=Toplevel(window)
    p = float(e0.get())
    pb = float(e1.get())
    t = float(e2.get())
    so = float(e3.get())
    sg = float(e4.get())
    nacl = float(e5.get())
    method1=e7.get()
    method2=e8.get()
    method3=e9.get()
    method4=e10.get()
    method5=e11.get()
    method6=e12.get()
    method7=e13.get()
    
    rho=Back.rho_Std(p,pb,t,sg,so)
    Bo=Back.BO(p,pb,t,so,sg,method1)
    gor=Back.GOR(p,pb,t,so,sg,method2)
    miuo=Back.MIUO(p,pb,t,so,sg,method3)
    co=Back.co_Vzq(p,pb,t,sg,so)
    z=Back.ZF(p,t,sg,method4)
    rhg=Back.rho_g(p,t,sg)
    bg=Back.Bg(p,t,sg)
    miug=Back.miug_lee(p,t,sg)
    cg=Back.CG(p,t,sg,method5)
    bw=Back.BW(p,pb,t,nacl,method6)
    rhw=Back.rhow_mcn(p,pb,t,nacl)
    miuw=Back.MIUW(p,t,nacl,method7)

    x=range(int(e0.get()),100,-100)
    y=[Back.Bg(p,t,sg) for p in x]
    fig=plt.Figure(figsize=(10,10))
    a=fig.add_subplot(111)
    a.plot(x,y)
    a.set_title('Gas FVF vs Pressure')
    a.set_xlabel('Pressure(Psia)')
    a.set_ylabel('Gas FVF(rcf/scf)')
    chart1=FigureCanvasTkAgg(fig,plotwindow)
    chart1.get_tk_widget().pack()
    
def MIUGPlot():
    plotwindow=Toplevel(window)
    p = float(e0.get())
    pb = float(e1.get())
    t = float(e2.get())
    so = float(e3.get())
    sg = float(e4.get())
    nacl = float(e5.get())
    method1=e7.get()
    method2=e8.get()
    method3=e9.get()
    method4=e10.get()
    method5=e11.get()
    method6=e12.get()
    method7=e13.get()
    
    rho=Back.rho_Std(p,pb,t,sg,so)
    Bo=Back.BO(p,pb,t,so,sg,method1)
    gor=Back.GOR(p,pb,t,so,sg,method2)
    miuo=Back.MIUO(p,pb,t,so,sg,method3)
    co=Back.co_Vzq(p,pb,t,sg,so)
    z=Back.ZF(p,t,sg,method4)
    rhg=Back.rho_g(p,t,sg)
    bg=Back.Bg(p,t,sg)
    miug=Back.miug_lee(p,t,sg)
    cg=Back.CG(p,t,sg,method5)
    bw=Back.BW(p,pb,t,nacl,method6)
    rhw=Back.rhow_mcn(p,pb,t,nacl)
    miuw=Back.MIUW(p,t,nacl,method7)

    x=range(int(e0.get()),100,-100)
    y=[Back.miug_lee(p,t,sg) for p in x]
    fig=plt.Figure(figsize=(10,10))
    a=fig.add_subplot(111)
    a.plot(x,y)
    a.set_title('Gas Viscosity vs Pressure')
    a.set_xlabel('Pressure(Psia)')
    a.set_ylabel('Gas Viscosity (cP)')
    chart1=FigureCanvasTkAgg(fig,plotwindow)
    chart1.get_tk_widget().pack()
    
def CGPlot():
    plotwindow=Toplevel(window)
    p = float(e0.get())
    pb = float(e1.get())
    t = float(e2.get())
    so = float(e3.get())
    sg = float(e4.get())
    nacl = float(e5.get())
    method1=e7.get()
    method2=e8.get()
    method3=e9.get()
    method4=e10.get()
    method5=e11.get()
    method6=e12.get()
    method7=e13.get()
    
    rho=Back.rho_Std(p,pb,t,sg,so)
    Bo=Back.BO(p,pb,t,so,sg,method1)
    gor=Back.GOR(p,pb,t,so,sg,method2)
    miuo=Back.MIUO(p,pb,t,so,sg,method3)
    co=Back.co_Vzq(p,pb,t,sg,so)
    z=Back.ZF(p,t,sg,method4)
    rhg=Back.rho_g(p,t,sg)
    bg=Back.Bg(p,t,sg)
    miug=Back.miug_lee(p,t,sg)
    cg=Back.CG(p,t,sg,method5)
    bw=Back.BW(p,pb,t,nacl,method6)
    rhw=Back.rhow_mcn(p,pb,t,nacl)
    miuw=Back.MIUW(p,t,nacl,method7)

    x=range(int(e0.get()),100,-100)
    y=[Back.CG(p,t,sg,method5) for p in x]
    fig=plt.Figure(figsize=(10,10))
    a=fig.add_subplot(111)
    a.plot(x,y)
    a.set_title('Gas Compressibility vs Pressure')
    a.set_xlabel('Pressure(Psia)')
    a.set_ylabel('Gas Compressibility (1/Psia)')
    chart1=FigureCanvasTkAgg(fig,plotwindow)
    chart1.get_tk_widget().pack()

def BWPlot():
    plotwindow=Toplevel(window)
    p = float(e0.get())
    pb = float(e1.get())
    t = float(e2.get())
    so = float(e3.get())
    sg = float(e4.get())
    nacl = float(e5.get())
    method1=e7.get()
    method2=e8.get()
    method3=e9.get()
    method4=e10.get()
    method5=e11.get()
    method6=e12.get()
    method7=e13.get()
    
    rho=Back.rho_Std(p,pb,t,sg,so)
    Bo=Back.BO(p,pb,t,so,sg,method1)
    gor=Back.GOR(p,pb,t,so,sg,method2)
    miuo=Back.MIUO(p,pb,t,so,sg,method3)
    co=Back.co_Vzq(p,pb,t,sg,so)
    z=Back.ZF(p,t,sg,method4)
    rhg=Back.rho_g(p,t,sg)
    bg=Back.Bg(p,t,sg)
    miug=Back.miug_lee(p,t,sg)
    cg=Back.CG(p,t,sg,method5)
    bw=Back.BW(p,pb,t,nacl,method6)
    rhw=Back.rhow_mcn(p,pb,t,nacl)
    miuw=Back.MIUW(p,t,nacl,method7)

    x=range(int(e0.get()),100,-100)
    y=[Back.BW(p,pb,t,nacl,method6) for p in x]
    fig=plt.Figure(figsize=(10,10))
    a=fig.add_subplot(111)
    a.plot(x,y)
    a.set_title('Water FVF vs Pressure')
    a.set_xlabel('Pressure(Psia)')
    a.set_ylabel('Water FVF (rb/stb)')
    chart1=FigureCanvasTkAgg(fig,plotwindow)
    chart1.get_tk_widget().pack()
    
def RHOWPlot():
    plotwindow=Toplevel(window)
    p = float(e0.get())
    pb = float(e1.get())
    t = float(e2.get())
    so = float(e3.get())
    sg = float(e4.get())
    nacl = float(e5.get())
    method1=e7.get()
    method2=e8.get()
    method3=e9.get()
    method4=e10.get()
    method5=e11.get()
    method6=e12.get()
    method7=e13.get()
    
    rho=Back.rho_Std(p,pb,t,sg,so)
    Bo=Back.BO(p,pb,t,so,sg,method1)
    gor=Back.GOR(p,pb,t,so,sg,method2)
    miuo=Back.MIUO(p,pb,t,so,sg,method3)
    co=Back.co_Vzq(p,pb,t,sg,so)
    z=Back.ZF(p,t,sg,method4)
    rhg=Back.rho_g(p,t,sg)
    bg=Back.Bg(p,t,sg)
    miug=Back.miug_lee(p,t,sg)
    cg=Back.CG(p,t,sg,method5)
    bw=Back.BW(p,pb,t,nacl,method6)
    rhw=Back.rhow_mcn(p,pb,t,nacl)
    miuw=Back.MIUW(p,t,nacl,method7)

    x=range(int(e0.get()),100,-100)
    y=[Back.rhow_mcn(p,pb,t,nacl) for p in x]
    fig=plt.Figure(figsize=(10,10))
    a=fig.add_subplot(111)
    a.plot(x,y)
    a.set_title('Water Density vs Pressure')
    a.set_xlabel('Pressure(Psia)')
    a.set_ylabel('Water Density (lb/ft3)')
    chart1=FigureCanvasTkAgg(fig,plotwindow)
    chart1.get_tk_widget().pack()
    
def MIUWPlot():
    plotwindow=Toplevel(window)
    p = float(e0.get())
    pb = float(e1.get())
    t = float(e2.get())
    so = float(e3.get())
    sg = float(e4.get())
    nacl = float(e5.get())
    method1=e7.get()
    method2=e8.get()
    method3=e9.get()
    method4=e10.get()
    method5=e11.get()
    method6=e12.get()
    method7=e13.get()
    
    rho=Back.rho_Std(p,pb,t,sg,so)
    Bo=Back.BO(p,pb,t,so,sg,method1)
    gor=Back.GOR(p,pb,t,so,sg,method2)
    miuo=Back.MIUO(p,pb,t,so,sg,method3)
    co=Back.co_Vzq(p,pb,t,sg,so)
    z=Back.ZF(p,t,sg,method4)
    rhg=Back.rho_g(p,t,sg)
    bg=Back.Bg(p,t,sg)
    miug=Back.miug_lee(p,t,sg)
    cg=Back.CG(p,t,sg,method5)
    bw=Back.BW(p,pb,t,nacl,method6)
    rhw=Back.rhow_mcn(p,pb,t,nacl)
    miuw=Back.MIUW(p,t,nacl,method7)

    x=range(int(e0.get()),100,-100)
    y=[Back.MIUW(p,t,nacl,method7) for p in x]
    fig=plt.Figure(figsize=(10,10))
    a=fig.add_subplot(111)
    a.plot(x,y)
    a.set_title('Water Viscosity vs Pressure')
    a.set_xlabel('Pressure(Psia)')
    a.set_ylabel('Water Viscosity (cP)')
    chart1=FigureCanvasTkAgg(fig,plotwindow)
    chart1.get_tk_widget().pack()
           
menubar = Menu(window)
filemenu = Menu(menubar,tearoff=0)
filemenu.add_command(label='New')
filemenu.add_command(label='Open')
filemenu.add_command(label='Close',command = window.destroy)
menubar.add_cascade(label='File',menu=filemenu)

editmenu = Menu(menubar,tearoff=0)
editmenu.add_command(label='Undo')
editmenu.add_command(label='Cut')
editmenu.add_command(label='Copy')
editmenu.add_command(label='Paste')
menubar.add_cascade(label='Edit',menu=editmenu)

plotmenu = Menu(menubar,tearoff=0)
plotmenu.add_command(label='Gas Oil Ratio vs Pressure',command=GORPlot)
plotmenu.add_command(label='Density vs Pressure',command=RHOOPlot)
plotmenu.add_command(label='Formation Volume Factor vs Pressure',command=BOPlot)
plotmenu.add_command(label='Viscosity vs Pressure',command=MIUOPlot)
plotmenu.add_command(label='Compressibility vs Pressure',command=COPlot)
menubar.add_cascade(label='Oil Plot',menu=plotmenu)

plotmenu = Menu(menubar,tearoff=0)
plotmenu.add_command(label='Z Factor vs Pressure',command=ZPlot)
plotmenu.add_command(label='Density vs Pressure',command=RHOGPlot)
plotmenu.add_command(label='Formation Volume Factor vs Pressure',command=BGPlot)
plotmenu.add_command(label='Viscosity vs Pressure',command=MIUGPlot)
plotmenu.add_command(label='Compressibility vs Pressure',command=CGPlot)
menubar.add_cascade(label='Gas Plot',menu=plotmenu)

plotmenu = Menu(menubar,tearoff=0)
plotmenu.add_command(label='Formation Volume Factor vs Pressure',command=BWPlot)
plotmenu.add_command(label='Density vs Pressure',command=RHOWPlot)
plotmenu.add_command(label='Viscosity vs Pressure',command=MIUWPlot)
menubar.add_cascade(label='Water Plot',menu=plotmenu)

helpmenu = Menu(menubar,tearoff=0)
helpmenu.add_command(label='About')
menubar.add_cascade(label='Help',menu=helpmenu)


window.config(menu=menubar)



l0 = Label(window,text = "Pressure(Psia)")
l0.grid(row = 0, column = 0)
l1 = Label(window,text = "Bubble Pressure(Psia)")
l1.grid(row = 1, column = 0)
l2 = Label(window,text = "Temperature(°F)")
l2.grid(row = 2, column = 0)
l3 = Label(window,text = "Oil Gravity")
l3.grid(row = 3, column = 0)
l4 = Label(window,text = "Gas Gravity")
l4.grid(row = 4, column = 0)
l5 = Label(window,text = "Salinity(ppm)")
l5.grid(row = 5, column = 0)
l6 = Label(window,text = "Correlation",font=('Helvetica', 11, 'bold'))
l6.grid(row = 6, column = 0)
l7 = Label(window,text = "FVF Oil")
l7.grid(row = 7, column = 0)
l8 = Label(window,text = "Gas Oil Ratio")
l8.grid(row = 8, column = 0)
l9 = Label(window,text = "Oil Viscosity")
l9.grid(row = 9, column = 0)
l10 = Label(window,text = "Z Factor")
l10.grid(row = 10, column = 0)
l11 = Label(window,text = "Gas Compressibility")
l11.grid(row = 11, column = 0)
l12 = Label(window,text = "FVF Water")
l12.grid(row = 12, column = 0)
l13 = Label(window,text = "Water Viscosity")
l13.grid(row = 13, column = 0)


Pressure_text = StringVar()
e0 = Entry ( window, textvariable = Pressure_text)
e0.grid(row = 0, column = 1)

Bubble_text = StringVar()
e1 = Entry ( window, textvariable = Bubble_text)
e1.grid(row = 1, column = 1)


Temperature_text = StringVar()
e2 = Entry ( window, textvariable = Temperature_text)
e2.grid(row = 2, column = 1)

OilGravity_text = StringVar()
e3 = Entry ( window, textvariable = OilGravity_text)
e3.grid(row = 3, column = 1)

GasGravity_text = StringVar()
e4 = Entry ( window, textvariable = GasGravity_text)
e4.grid(row = 4, column = 1)

Salinity_text = StringVar()
e5 = Entry ( window, textvariable = Salinity_text)
e5.grid(row = 5, column = 1)

e7 = Combobox(window)
e7["values"] = ('Standing','Vasquez&Begg','Petrosky','Farshad','Marhoun','Kartoatmodjo','Almedhaideb','Shammasi','Sharkawy')
e7.grid(row = 7,column = 1)

e8 = Combobox(window)
e8["values"] = ('Standing','Vasquez&Begg','Lasater','Petrosky&Farshad','Kartoatmodjo')
e8.grid(row = 8,column = 1)

e9 = Combobox(window)
e9["values"] = ('Khan','Begss','Beal')
e9.grid(row = 9,column = 1)

e10 = Combobox(window)
e10["values"] = ('Papay','Dranchuk Abou Kassem','Hall Yaborough')
e10.grid(row = 10,column = 1)

e11 = Combobox(window)
e11["values"] = ('Hall Yaborough','Dranchuk Abou Kassem')
e11.grid(row = 11,column = 1)

e12 = Combobox(window)
e12["values"] = ('Meehan','Mc Cain')
e12.grid(row = 12,column = 1)

e13 = Combobox(window)
e13["values"] = ('Meehan','Mc Cain')
e13.grid(row = 13,column = 1)

r0 = Label(window,text = "Oil Density(lb/cuft)")
r0.grid(row = 0, column = 3)
r1 = Label(window,text = "Oil Formation Volume Factor(rb/stb)")
r1.grid(row = 1, column = 3)
r2 = Label(window,text = "Gas Oil Ratio(scf/stb)")
r2.grid(row = 2, column = 3)
r3 = Label(window,text = "Oil Viscosity(cP)")
r3.grid(row = 3, column = 3)
r4 = Label(window,text = "Oil Compressibility(1/Psia)")
r4.grid(row = 4, column = 3)
r5 = Label(window,text = "Z Factor")
r5.grid(row = 5, column = 3)
r6 = Label(window,text = "Gas Density(lb/cuft)")
r6.grid(row = 6, column = 3)
r7 = Label(window,text = "Gas Formation Volume Factor")
r7.grid(row = 7, column = 3)
r8 = Label(window,text = "Gas Viscosity(cp)")
r8.grid(row = 8, column = 3)
r9 = Label(window,text = "Gas Compressibility(1/Psia)")
r9.grid(row = 9, column = 3)
r10 = Label(window,text = "Water Formation Volume Factor(rb/stb)")
r10.grid(row = 10, column = 3)
r11 = Label(window,text = "Water Density(lb/cuft)")
r11.grid(row = 11, column = 3)
r12 = Label(window,text = "Water Viscosity(cP)")
r12.grid(row = 12, column = 3)


m1 = Label(window,text = "P(Psia)       ρo(lb/ft3)       Bo(rb/stb)       GOR(scf/stb)       μo(cP)       Co(1/Psia)        z(v/v)        ρg(lb/ft3)       Bg(rcf/scf)       μg(cP)       Cg(1/Psia)       Bw(rb/stb)       ρw(lb/ft3)       μw(cP)")
m1.grid(row = 14, column = 0, columnspan = 8)


Dens_text = StringVar()
E0 = Entry ( window, textvariable = Dens_text)
E0.grid(row = 0, column = 4)
FVF_text = StringVar()
E1 = Entry ( window, textvariable = FVF_text)
E1.grid(row = 1, column = 4)
GOR_text = StringVar()
E2 = Entry ( window, textvariable = GOR_text)
E2.grid(row = 2, column = 4)
MIUO_text = StringVar()
E3 = Entry ( window, textvariable = MIUO_text)
E3.grid(row = 3, column = 4)
CO_text = StringVar()
E4 = Entry ( window, textvariable = CO_text)
E4.grid(row = 4, column = 4)
Z_text = StringVar()
E5 = Entry ( window, textvariable = Z_text)
E5.grid(row = 5, column = 4)
GDens_text = StringVar()
E6 = Entry ( window, textvariable = GDens_text)
E6.grid(row = 6, column = 4)
BG_text = StringVar()
E7 = Entry ( window, textvariable = BG_text)
E7.grid(row = 7, column = 4)
MIUG_text = StringVar()
E8 = Entry ( window, textvariable = MIUG_text)
E8.grid(row = 8, column = 4)
CG_text = StringVar()
E9 = Entry ( window, textvariable = CG_text)
E9.grid(row = 9, column = 4)
WFVF_text = StringVar()
E10 = Entry ( window, textvariable = WFVF_text)
E10.grid(row = 10, column = 4)
WDens_text = StringVar()
E11 = Entry ( window, textvariable = WDens_text)
E11.grid(row = 11, column = 4)
MIUW_text = StringVar()
E12 = Entry ( window, textvariable = MIUW_text)
E12.grid(row = 12, column = 4)

b1 = Button(window,text="Calculate",width=10,command=calculate)
b1.grid(row=0,column=2)

b2 = Button(window,text="Run",width=10,command=Run)
b2.grid(row=1,column=2)

b3 = Button(window,text="Clear",width=10,command = clear)
b3.grid(row=2,column=2)

table1 = scrolledtext.ScrolledText(window,height = 20, width = 120 )
table1.grid(row=15, column = 0, columnspan = 8)


window.mainloop()
